# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
#  __Luis Alberto Meza__
# <br> Data scientist

# %% [markdown]
# _I'm interested in Data science because the way that is used to explain natural and social phenomena... and because is a profitable work_

# %% [markdown]
# ### In the following code I'll proceed to do the hardest operation on the world

# %%
1+1
# Out:
# 2

# %% [markdown]
# - Bacterias
#      - _Staphylococcus aureus_
#      - _Moraxella catharralis_
#      - _Bacillus_ spp.
#
# 1. Fungi
#      1. _Agaricus ugustus_
#      2. _Amanita_ sp
#      3. _Fuligo_ sp.
#
# | Bacterias | Fungi |
# | ----| ----|
# | _Staphylococcus aureus_  | _Agaricus ugustus_  |
# | _Moraxella catharralis_ | _Amanita_ sp |
# | _Bacillus_ spp. | _Fuligo_ sp. |
